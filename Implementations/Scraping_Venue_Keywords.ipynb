# %%
import requests
import pandas as pd
import numpy as np
import time
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
papers_df = pd.read_csv("papers_and_authors.csv")
papers_df.columns = [c.strip() for c in papers_df.columns]

venues = (
    papers_df["venue"]
    .dropna()
    .astype(str)
    .str.strip()
    .unique()
)

print(f"Found {len(venues)} unique venues")
# Out:
# Found 147 unique venues

# %%
API_KEY = 'qNb1kj6alf9Ttx6AmfnF28Pz63OSKR4h5MyDgR6k'

HEADERS = {
    "x-api-key": API_KEY
}

# %%
def fetch_semantic_scholar_texts(
    venue,
    max_papers=200,
    sleep_time=0.5
):
    """
    Fetch titles + abstracts for papers related to a venue
    using Semantic Scholar Graph API with API key.
    """
    url = "https://api.semanticscholar.org/graph/v1/paper/search"
    offset = 0
    limit = 100

    texts = []
    seen_ids = set()

    while len(texts) < max_papers:
        params = {
            "query": venue,
            "limit": limit,
            "offset": offset,
            "fields": "paperId,title,abstract"
        }

        r = requests.get(url, headers=HEADERS, params=params)

        if r.status_code != 200:
            print(f"  ❌ Request failed ({r.status_code})")
            break

        papers = r.json().get("data", [])
        if not papers:
            break

        for p in papers:
            pid = p.get("paperId")
            if pid in seen_ids:
                continue
            seen_ids.add(pid)

            title = p.get("title", "")
            abstract = p.get("abstract", "")

            text = f"{title} {abstract}".strip()
            if len(text) > 50:
                texts.append(text)

            if len(texts) >= max_papers:
                break

        offset += limit
        time.sleep(sleep_time)

    return texts

# %%
ACADEMIC_STOPWORDS = {
    "such","have","been","using","used","based","present","recent",
    "recently","various","different","approach","methods","results",
    "paper","study","studies","proposed","however","show","shows",
    "research","method","problem","system"
}

# %%
def extract_venue_keywords_semantic_scholar(
    venues,
    max_papers_per_venue=20,
    top_k=10
):
    rows = []

    for venue in venues:
        if venue.lower() in ["unknown", "nan", "arxiv", "arxiv.org"]:
            continue

        print(f"Processing venue: {venue}")

        texts = fetch_semantic_scholar_texts(
            venue,
            max_papers=max_papers_per_venue
        )

        if len(texts) < 10:
            print("  ❌ Insufficient papers")
            continue

        vectorizer = TfidfVectorizer(
            stop_words="english",
            ngram_range=(1, 2),
            max_features=3000
        )

        tfidf = vectorizer.fit_transform(texts)
        mean_scores = np.asarray(tfidf.mean(axis=0)).flatten()
        features = np.array(vectorizer.get_feature_names_out())

        # Remove academic filler words
        mask = [f not in ACADEMIC_STOPWORDS for f in features]
        features = features[mask]
        mean_scores = mean_scores[mask]

        top_idx = mean_scores.argsort()[::-1][:top_k]

        for i in top_idx:
            rows.append({
                "Venue": venue,
                "Keyword": features[i],
                "Weight": round(float(mean_scores[i]), 5)
            })

    return pd.DataFrame(rows)

# %%
venue_keywords_df = extract_venue_keywords_semantic_scholar(
    venues,
    max_papers_per_venue=20,
    top_k=10
)

venue_keywords_df.to_csv(
    "venue_common_keywords.csv",
    index=False
)

print("\nSaved venue keywords to venue_common_keywords.csv")
# Out:
# Processing venue: Neural Information Processing Systems
# Processing venue: International Conference on Learning Representations
# Processing venue: International Conference on Machine Learning
# Processing venue: Conference on Empirical Methods in Natural Language Processing
# Processing venue: Computer Vision and Pattern Recognition
# Processing venue: Conference of the European Chapter of the Association for Computational Linguistics
# Processing venue: Transactions of the Association for Computational Linguistics
# Processing venue: North American Chapter of the Association for Computational Linguistics
# Processing venue: Annual Meeting of the Association for Computational Linguistics
# Processing venue: Neural Computation
# Processing venue: International Conference on Computational Logic
# Processing venue: Journal of machine learning research
# Processing venue: Reliability Engineering & System Safety
# Processing venue: Information Fusion
# Processing venue: Biomedical Signal Processing and Control
# Processing venue: Information Sciences
# Processing venue: Information and Software Technology
# Processing venue: Advanced Engineering Informatics
# Processing venue: Optics and lasers in engineering
# Processing venue: Expert systems with applications
# Processing venue: Transportation Research Part E: Logistics and Transportation Review
# Processing venue: Journal of systems architecture
# Processing venue: Robotics and Autonomous Systems
# Processing venue: Journal of manufacturing systems
# Processing venue: Journal of Hydrology: Regional Studies
# Processing venue: Pattern Recognition
# Processing venue: Information Processing & Management
# Processing venue: Optics Communications
# Processing venue: Journal of Industrial Information Integration
# Processing venue: Results in Engineering
# Processing venue: Ad hoc networks
# Processing venue: Teaching and Teacher Education : An International Journal of Research and Studies
# Processing venue: Array
# Processing venue: Machine Learning with Applications
# Processing venue: EngMedicine
# Processing venue: Computers in Human Behavior Reports
# Processing venue: Resources, Conservation and Recycling
# Processing venue: Remote Sensing of Environment
# Processing venue: Agricultural and Forest Meteorology
# Processing venue: Intelligent Medicine
# Processing venue: International Journal of Informatics and Communication Technology (IJ-ICT)
# Processing venue: Neurocomputing
# Processing venue: Digital Signal Processing
# Processing venue: Acta Astronautica
# Processing venue: Computer Methods in Applied Mechanics and Engineering
# Processing venue: Sensors and Actuators A: Physical
# Processing venue: Composites Science And Technology
# Processing venue: Smart Agricultural Technology
# Processing venue: Applied Thermal Engineering
# Processing venue: Optics &amp; Laser Technology
# Processing venue: Signal Processing: Image Communication
# Processing venue: Applied Soft Computing
# Processing venue: Image and Vision Computing
# Processing venue: Transportation Research Part D: Transport and Environment
# Processing venue: Ocean Engineering
# Processing venue: Transportation Research Part F: Traffic Psychology and Behaviour
# Processing venue: International Communications in Heat and Mass Transfer
# Processing venue: Engineering structures
# Processing venue: Measurement
# Processing venue: Computers & electrical engineering
# Processing venue: Computers &amp; Industrial Engineering
# Processing venue: Journal of Hydrology
# Processing venue: Knowledge-Based Systems
# Processing venue: Journal of Power Sources
# Processing venue: Engineering applications of artificial intelligence
# Processing venue: Applied Energy
# Processing venue: Journal of Energy Storage
# Processing venue: Forensic Science International: Digital Investigation
# Processing venue: Journal of Stored Products Research
# Processing venue: Journal of international financial markets, institutions, and money
# Processing venue: Energy Policy
# Processing venue: IEEE transactions on computers
# Processing venue: Environmental Modelling &amp; Software
# Processing venue: Electric power systems research
# Processing venue: Computer Science Review
# Processing venue: Safety Science
# Processing venue: Computational Geosciences
# Processing venue: Transportation Research Part C: Emerging Technologies
# Processing venue: Colloids and Surfaces A: Physicochemical and Engineering Aspects
# Processing venue: Computers and Chemical Engineering
# Processing venue: Journal of Development Economics
# Processing venue: Signal processing. Image communication
# Processing venue: Journal of Transportation Engineering, Part A: Systems
# Processing venue: Renewable & Sustainable Energy Reviews
# Processing venue: Computers &amp; Fluids
# Processing venue: Composite structures
# Processing venue: Atmospheric research
# Processing venue: Solid-State Electronics
# Processing venue: Simulation modelling practice and theory
# Processing venue: Computers and Electronics in Agriculture
# Processing venue: Isprs Journal of Photogrammetry and Remote Sensing
# Processing venue: Chemometrics and Intelligent Laboratory Systems
# Processing venue: International Journal of Applied Earth Observation and Geoinformation
# Processing venue: Journal of Applied Geophysics
# Processing venue: Renewable Energy
# Processing venue: Computational materials science
# Processing venue: Automation in Construction
# Processing venue: Process Biochemistry
# Processing venue: IEEE Robotics and Automation Letters
# Processing venue: IEEE Transactions on Parallel and Distributed Systems
# Processing venue: Neuroscience
# Processing venue: Urban Climate
# Processing venue: Journal of Molecular Liquids
# Processing venue: Advances in Science and Technology Research Journal
# Processing venue: Energy Conversion and Management
# Processing venue: Electoral Studies
# Processing venue: Computer Networks
# Processing venue: Computer Vision and Image Understanding
# Processing venue: CATENA
# Processing venue: Computers &amp; Mathematics with Applications
# Processing venue: Mechanical systems and signal processing
# Processing venue: Materials &amp; Design
# Processing venue: IEEE Transactions on Knowledge and Data Engineering
# Processing venue: IEEE Transactions on Mobile Computing
# Processing venue: Journal of Atmospheric and Solar-Terrestrial Physics
# Processing venue: AEU - International Journal of Electronics and Communications
# Processing venue: Energy
# Processing venue: Sustainable cities and society
# Processing venue: Engineering Geology
# Processing venue: IEEE Computational Intelligence Magazine
# Processing venue: Chemical engineering research & design
# Processing venue: Results in Optics
# Processing venue: Swarm and Evolutionary Computation
# Processing venue: IEEE Transactions on Big Data
# Processing venue: IEEE Sensors Letters
# Processing venue: International Journal of Computer Vision
# Processing venue: Knowledge and Information Systems
# Processing venue: npj Biomedical Innovations
# Processing venue: PLoS ONE
# Processing venue: IEEE Sensors Journal
# Processing venue: IEEE Internet of Things Journal
# Processing venue: Engineering computations
# Processing venue: ACM Computing Surveys
# Processing venue: Nucleic Acids Research
# Processing venue: Frontiers in Big Data
# Processing venue: Frontiers of Computer Science
# Processing venue: Journal of Advanced Trends in Medical Research
# Processing venue: Frontiers in Cardiovascular Medicine
# Processing venue: Buildings
# Processing venue: Frontiers in Neurology
# Processing venue: bioRxiv
# Processing venue: Environmental Monitoring & Assessment
# Processing venue: IEEE Transactions on Dependable and Secure Computing
# Processing venue: Nature Communications
# Processing venue: Cluster Computing
#
# Saved venue keywords to venue_common_keywords.csv
